# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_11051/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
from keras.datasets import fashion_mnist
import keras
import matplotlib.pyplot as plt

fashion_mnist=keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# 2024-02-13 10:30:13.844533: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-13 10:30:13.844574: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-13 10:30:13.845597: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-13 10:30:13.851699: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-13 10:30:14.653309: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class NeuralNetwork:
    def __init__(self, layer_sizes):
        self.layer_sizes = layer_sizes
        self.parameters = self.initialize_parameters()
    
    def initialize_parameters(self):
        parameters = {}
        for l in range(1, len(self.layer_sizes)):
            parameters['W' + str(l)] = np.random.randn(self.layer_sizes[l], self.layer_sizes[l-1]) * 0.01
            parameters['b' + str(l)] = np.zeros((self.layer_sizes[l], 1))
        return parameters

    def relu(self, Z):
        return np.maximum(0, Z)
    
    def softmax(self, Z):
        expZ = np.exp(Z - np.max(Z))
        return expZ / expZ.sum(axis=0, keepdims=True)
    
    def compute_loss(self, Y, Y_hat):
        m = Y.shape[1]
        loss = -np.sum(Y * np.log(Y_hat + 1e-9)) / m
        return loss
    
    def forward_propagation(self, X):
        caches = {}
        A = X
        L = len(self.parameters) // 2
        
        for l in range(1, L):
            A_prev = A
            Z = np.dot(self.parameters['W' + str(l)], A_prev) + self.parameters['b' + str(l)]
            A = self.relu(Z)
            caches['Z' + str(l)] = Z
            caches['A' + str(l)] = A
        
        ZL = np.dot(self.parameters['W' + str(L)], A) + self.parameters['b' + str(L)]
        AL = self.softmax(ZL)
        caches['Z' + str(L)] = ZL
        caches['A' + str(L)] = AL
        return AL, caches
    
    def backpropagation(self, X, Y, caches):
        grads = {}
        L = len(self.parameters) // 2  # Number of layers
        m = X.shape[1]
        Y = Y.reshape(caches['A' + str(L)].shape)  # Ensure same shape as output layer

        # Initializing backpropagation
        dZL = caches['A' + str(L)] - Y
        grads["dW" + str(L)] = 1./m * np.dot(dZL, caches['A' + str(L-1)].T)
        grads["db" + str(L)] = 1./m * np.sum(dZL, axis=1, keepdims=True)

        for l in reversed(range(1, L)):
            dA_prev = np.dot(self.parameters["W" + str(l+1)].T, dZL)
            dZL = np.array(dA_prev, copy=True)
            dZL[caches['Z' + str(l)] <= 0] = 0  # ReLU backward
            if l > 1:
                grads["dW" + str(l)] = 1./m * np.dot(dZL, caches['A' + str(l-1)].T)
            else:  # For the first hidden layer, use X as A0
                grads["dW" + str(l)] = 1./m * np.dot(dZL, X.T)
            grads["db" + str(l)] = 1./m * np.sum(dZL, axis=1, keepdims=True)
            dZL = dA_prev  # Prepare dZL for next layer (if not the first layer)

        return grads
    
    def update_parameters(self, grads, learning_rate):
        L = len(self.parameters) // 2
        for l in range(L):
            self.parameters["W" + str(l+1)] -= learning_rate * grads["dW" + str(l+1)]
            self.parameters["b" + str(l+1)] -= learning_rate * grads["db" + str(l+1)]

# %%
def convert_labels_to_one_hot(labels, classes):
    return np.eye(classes)[labels].T

def preprocess_data(train_images, train_labels, test_images, test_labels):
    X_train = train_images.reshape(train_images.shape[0], -1).T / 255.
    X_test = test_images.reshape(test_images.shape[0], -1).T / 255.
    
    Y_train = convert_labels_to_one_hot(train_labels, 10)
    Y_test = convert_labels_to_one_hot(test_labels, 10)
    
    return X_train, Y_train, X_test, Y_test

def plot_training_loss_and_test_acc(epochs, traing_loss, test_accuracy):
    epochs_range = list(range(0, epochs))
    plt.figure(figsize=(10, 5))
    plt.plot(epochs_range, traing_loss, label='Training Loss')
    plt.plot(epochs_range, test_accuracy, label='Test Accuracy')
    plt.title('Training Loss and Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss/Accuracy')
    plt.legend()
    plt.show()

# %%
def train(X_train, Y_train, X_test, Y_test, epochs=10, learning_rate=0.01):
    np.random.seed(1) 
    nn = NeuralNetwork([X_train.shape[0], 64, 10])
    
    # traing_loss, test_accuracy = [], []
    
    for epoch in range(epochs):
        AL, caches = nn.forward_propagation(X_train)
        loss = nn.compute_loss(Y_train, AL)
        grads = nn.backpropagation(X_train, Y_train, caches)
        nn.update_parameters(grads, learning_rate)
        
        if epoch % 1 == 0:
            print("Epoch %i, Training loss: %f" % (epoch, loss))
    
            # Evaluate model on whole test data after each epoch
            predictions, _ = nn.forward_propagation(X_test)
            accuracy = np.mean(np.argmax(predictions, axis=0) == np.argmax(Y_test, axis=0))
            print(f"Test accuracy : {accuracy}\n")
            
            # traing_loss.append(loss)
            # test_accuracy.append(accuracy)
    
    # plot_training_loss_and_test_acc(epochs, traing_loss, test_accuracy)

X_train, Y_train, X_test, Y_test = preprocess_data(train_images, train_labels, test_images, test_labels)
train(X_train, Y_train, X_test, Y_test, epochs=300, learning_rate=0.1)
# Out:
# Epoch 0, Training loss: 2.302585
# Test accuracy : 0.102
#
# Epoch 1, Training loss: 2.302585
# Test accuracy : 0.1052
#
# Epoch 2, Training loss: 2.302585
# Test accuracy : 0.1096
#
# Epoch 3, Training loss: 2.302585
# Test accuracy : 0.1141
#
# Epoch 4, Training loss: 2.302584
# Test accuracy : 0.1202
#
# Epoch 5, Training loss: 2.302584
# Test accuracy : 0.1243
#
# Epoch 6, Training loss: 2.302584
# Test accuracy : 0.1284
#
# Epoch 7, Training loss: 2.302584
# Test accuracy : 0.1307
#
# Epoch 8, Training loss: 2.302584
# Test accuracy : 0.1325
#
# Epoch 9, Training loss: 2.302584
# Test accuracy : 0.1352
#
# Epoch 10, Training loss: 2.302584
# Test accuracy : 0.135
#
# Epoch 11, Training loss: 2.302584
# Test accuracy : 0.1359
#
# Epoch 12, Training loss: 2.302584
# Test accuracy : 0.1384
#
# Epoch 13, Training loss: 2.302584
# Test accuracy : 0.1401
#
# Epoch 14, Training loss: 2.302584
# Test accuracy : 0.1432
#
# Epoch 15, Training loss: 2.302584
# Test accuracy : 0.1458
#
# Epoch 16, Training loss: 2.302584
# Test accuracy : 0.1482
#
# Epoch 17, Training loss: 2.302584
# Test accuracy : 0.1514
#
# Epoch 18, Training loss: 2.302584
# Test accuracy : 0.1531
#
# Epoch 19, Training loss: 2.302584
# Test accuracy : 0.1549
#
# Epoch 20, Training loss: 2.302584
# Test accuracy : 0.1566
#
# Epoch 21, Training loss: 2.302584
# Test accuracy : 0.1567
#
# Epoch 22, Training loss: 2.302584
# Test accuracy : 0.158
#
# Epoch 23, Training loss: 2.302584
# Test accuracy : 0.1589
#
# Epoch 24, Training loss: 2.302584
# Test accuracy : 0.1607
#
# Epoch 25, Training loss: 2.302584
# Test accuracy : 0.1624
#
# Epoch 26, Training loss: 2.302584
# Test accuracy : 0.1638
#
# Epoch 27, Training loss: 2.302584
# Test accuracy : 0.165
#
# Epoch 28, Training loss: 2.302584
# Test accuracy : 0.1651
#
# Epoch 29, Training loss: 2.302584
# Test accuracy : 0.1664
#
# Epoch 30, Training loss: 2.302584
# Test accuracy : 0.1666
#
# Epoch 31, Training loss: 2.302584
# Test accuracy : 0.1667
#
# Epoch 32, Training loss: 2.302584
# Test accuracy : 0.1674
#
# Epoch 33, Training loss: 2.302584
# Test accuracy : 0.1684
#
# Epoch 34, Training loss: 2.302584
# Test accuracy : 0.1687
#
# Epoch 35, Training loss: 2.302584
# Test accuracy : 0.1681
#
# Epoch 36, Training loss: 2.302584
# Test accuracy : 0.1667
#
# Epoch 37, Training loss: 2.302584
# Test accuracy : 0.1635
#
# Epoch 38, Training loss: 2.302584
# Test accuracy : 0.1633
#
# Epoch 39, Training loss: 2.302584
# Test accuracy : 0.1649
#
# Epoch 40, Training loss: 2.302584
# Test accuracy : 0.1687
#
# Epoch 41, Training loss: 2.302584
# Test accuracy : 0.1731
#
# Epoch 42, Training loss: 2.302584
# Test accuracy : 0.1762
#
# Epoch 43, Training loss: 2.302584
# Test accuracy : 0.1793
#
# Epoch 44, Training loss: 2.302584
# Test accuracy : 0.1827
#
# Epoch 45, Training loss: 2.302583
# Test accuracy : 0.1843
#
# Epoch 46, Training loss: 2.302583
# Test accuracy : 0.1849
#
# Epoch 47, Training loss: 2.302583
# Test accuracy : 0.1851
#
# Epoch 48, Training loss: 2.302583
# Test accuracy : 0.1858
#
# Epoch 49, Training loss: 2.302583
# Test accuracy : 0.1871
#
# Epoch 50, Training loss: 2.302583
# Test accuracy : 0.187
#
# Epoch 51, Training loss: 2.302583
# Test accuracy : 0.1866
#
# Epoch 52, Training loss: 2.302583
# Test accuracy : 0.187
#
# Epoch 53, Training loss: 2.302583
# Test accuracy : 0.186
#
# Epoch 54, Training loss: 2.302583
# Test accuracy : 0.1856
#
# Epoch 55, Training loss: 2.302583
# Test accuracy : 0.1853
#
# Epoch 56, Training loss: 2.302583
# Test accuracy : 0.1851
#
# Epoch 57, Training loss: 2.302583
# Test accuracy : 0.185
#
# Epoch 58, Training loss: 2.302583
# Test accuracy : 0.1854
#
# Epoch 59, Training loss: 2.302583
# Test accuracy : 0.1861
#
# Epoch 60, Training loss: 2.302583
# Test accuracy : 0.1865
#
# Epoch 61, Training loss: 2.302583
# Test accuracy : 0.1868
#
# Epoch 62, Training loss: 2.302583
# Test accuracy : 0.1864
#
# Epoch 63, Training loss: 2.302583
# Test accuracy : 0.1855
#
# Epoch 64, Training loss: 2.302583
# Test accuracy : 0.1855
#
# Epoch 65, Training loss: 2.302583
# Test accuracy : 0.1854
#
# Epoch 66, Training loss: 2.302583
# Test accuracy : 0.1858
#
# Epoch 67, Training loss: 2.302583
# Test accuracy : 0.1852
#
# Epoch 68, Training loss: 2.302583
# Test accuracy : 0.1854
#
# Epoch 69, Training loss: 2.302583
# Test accuracy : 0.1846
#
# Epoch 70, Training loss: 2.302583
# Test accuracy : 0.184
#
# Epoch 71, Training loss: 2.302583
# Test accuracy : 0.1828
#
# Epoch 72, Training loss: 2.302583
# Test accuracy : 0.1819
#
# Epoch 73, Training loss: 2.302583
# Test accuracy : 0.1816
#
# Epoch 74, Training loss: 2.302583
# Test accuracy : 0.1803
#
# Epoch 75, Training loss: 2.302583
# Test accuracy : 0.1793
#
# Epoch 76, Training loss: 2.302583
# Test accuracy : 0.179
#
# Epoch 77, Training loss: 2.302583
# Test accuracy : 0.178
#
# Epoch 78, Training loss: 2.302583
# Test accuracy : 0.1767
#
# Epoch 79, Training loss: 2.302583
# Test accuracy : 0.1763
#
# Epoch 80, Training loss: 2.302583
# Test accuracy : 0.1758
#
# Epoch 81, Training loss: 2.302583
# Test accuracy : 0.1751
#
# Epoch 82, Training loss: 2.302583
# Test accuracy : 0.1744
#
# Epoch 83, Training loss: 2.302583
# Test accuracy : 0.1732
#
# Epoch 84, Training loss: 2.302583
# Test accuracy : 0.1715
#
# Epoch 85, Training loss: 2.302583
# Test accuracy : 0.1697
#
# Epoch 86, Training loss: 2.302583
# Test accuracy : 0.1681
#
# Epoch 87, Training loss: 2.302583
# Test accuracy : 0.1652
#
# Epoch 88, Training loss: 2.302583
# Test accuracy : 0.1635
#
# Epoch 89, Training loss: 2.302583
# Test accuracy : 0.1626
#
# Epoch 90, Training loss: 2.302583
# Test accuracy : 0.1595
#
# Epoch 91, Training loss: 2.302583
# Test accuracy : 0.1573
#
# Epoch 92, Training loss: 2.302583
# Test accuracy : 0.1536
#
# Epoch 93, Training loss: 2.302583
# Test accuracy : 0.1497
#
# Epoch 94, Training loss: 2.302583
# Test accuracy : 0.1469
#
# Epoch 95, Training loss: 2.302583
# Test accuracy : 0.1429
#
# Epoch 96, Training loss: 2.302583
# Test accuracy : 0.1358
#
# Epoch 97, Training loss: 2.302583
# Test accuracy : 0.1321
#
# Epoch 98, Training loss: 2.302583
# Test accuracy : 0.1325
#
# Epoch 99, Training loss: 2.302583
# Test accuracy : 0.1314
#
# Epoch 100, Training loss: 2.302583
# Test accuracy : 0.1321
#
# Epoch 101, Training loss: 2.302583
# Test accuracy : 0.1324
#
# Epoch 102, Training loss: 2.302583
# Test accuracy : 0.1328
#
# Epoch 103, Training loss: 2.302583
# Test accuracy : 0.1336
#
# Epoch 104, Training loss: 2.302583
# Test accuracy : 0.1331
#
# Epoch 105, Training loss: 2.302583
# Test accuracy : 0.1332
#
# Epoch 106, Training loss: 2.302583
# Test accuracy : 0.1334
#
# Epoch 107, Training loss: 2.302583
# Test accuracy : 0.1335
#
# Epoch 108, Training loss: 2.302583
# Test accuracy : 0.1335
#
# Epoch 109, Training loss: 2.302583
# Test accuracy : 0.1333
#
# Epoch 110, Training loss: 2.302583
# Test accuracy : 0.1339
#
# Epoch 111, Training loss: 2.302583
# Test accuracy : 0.1341
#
# Epoch 112, Training loss: 2.302583
# Test accuracy : 0.134
#
# Epoch 113, Training loss: 2.302583
# Test accuracy : 0.1336
#
# Epoch 114, Training loss: 2.302583
# Test accuracy : 0.1334
#
# Epoch 115, Training loss: 2.302583
# Test accuracy : 0.1335
#
# Epoch 116, Training loss: 2.302583
# Test accuracy : 0.1341
#
# Epoch 117, Training loss: 2.302583
# Test accuracy : 0.1342
#
# Epoch 118, Training loss: 2.302583
# Test accuracy : 0.1347
#
# Epoch 119, Training loss: 2.302583
# Test accuracy : 0.1352
#
# Epoch 120, Training loss: 2.302583
# Test accuracy : 0.135
#
# Epoch 121, Training loss: 2.302583
# Test accuracy : 0.1353
#
# Epoch 122, Training loss: 2.302583
# Test accuracy : 0.1353
#
# Epoch 123, Training loss: 2.302583
# Test accuracy : 0.1355
#
# Epoch 124, Training loss: 2.302583
# Test accuracy : 0.1363
#
# Epoch 125, Training loss: 2.302583
# Test accuracy : 0.1364
#
# Epoch 126, Training loss: 2.302583
# Test accuracy : 0.1365
#
# Epoch 127, Training loss: 2.302583
# Test accuracy : 0.1365
#
# Epoch 128, Training loss: 2.302583
# Test accuracy : 0.137
#
# Epoch 129, Training loss: 2.302583
# Test accuracy : 0.1372
#
# Epoch 130, Training loss: 2.302583
# Test accuracy : 0.1376
#
# Epoch 131, Training loss: 2.302583
# Test accuracy : 0.1377
#
# Epoch 132, Training loss: 2.302583
# Test accuracy : 0.1382
#
# Epoch 133, Training loss: 2.302583
# Test accuracy : 0.1387
#
# Epoch 134, Training loss: 2.302583
# Test accuracy : 0.1394
#
# Epoch 135, Training loss: 2.302583
# Test accuracy : 0.1396
#
# Epoch 136, Training loss: 2.302583
# Test accuracy : 0.1399
#
# Epoch 137, Training loss: 2.302583
# Test accuracy : 0.1405
#
# Epoch 138, Training loss: 2.302583
# Test accuracy : 0.1413
#
# Epoch 139, Training loss: 2.302583
# Test accuracy : 0.1422
#
# Epoch 140, Training loss: 2.302583
# Test accuracy : 0.1426
#
# Epoch 141, Training loss: 2.302583
# Test accuracy : 0.1438
# Epoch 142, Training loss: 2.302583
# Test accuracy : 0.1443
#
# Epoch 143, Training loss: 2.302583
# Test accuracy : 0.1453
#
# Epoch 144, Training loss: 2.302583
# Test accuracy : 0.1458
#
# Epoch 145, Training loss: 2.302583
# Test accuracy : 0.1464
#
# Epoch 146, Training loss: 2.302583
# Test accuracy : 0.1475
#
# Epoch 147, Training loss: 2.302583
# Test accuracy : 0.148
#
# Epoch 148, Training loss: 2.302583
# Test accuracy : 0.1485
#
# Epoch 149, Training loss: 2.302583
# Test accuracy : 0.1497
#
# Epoch 150, Training loss: 2.302583
# Test accuracy : 0.1497
#
# Epoch 151, Training loss: 2.302583
# Test accuracy : 0.1497
#
# Epoch 152, Training loss: 2.302583
# Test accuracy : 0.1509
#
# Epoch 153, Training loss: 2.302583
# Test accuracy : 0.1514
#
# Epoch 154, Training loss: 2.302583
# Test accuracy : 0.1527
#
# Epoch 155, Training loss: 2.302583
# Test accuracy : 0.1528
#
# Epoch 156, Training loss: 2.302583
# Test accuracy : 0.1541
#
# Epoch 157, Training loss: 2.302583
# Test accuracy : 0.1564
#
# Epoch 158, Training loss: 2.302583
# Test accuracy : 0.1569
#
# Epoch 159, Training loss: 2.302583
# Test accuracy : 0.1578
#
# Epoch 160, Training loss: 2.302583
# Test accuracy : 0.1601
#
# Epoch 161, Training loss: 2.302583
# Test accuracy : 0.1618
#
# Epoch 162, Training loss: 2.302583
# Test accuracy : 0.1636
#
# Epoch 163, Training loss: 2.302583
# Test accuracy : 0.1663
#
# Epoch 164, Training loss: 2.302583
# Test accuracy : 0.168
#
# Epoch 165, Training loss: 2.302583
# Test accuracy : 0.1697
#
# Epoch 166, Training loss: 2.302583
# Test accuracy : 0.171
#
# Epoch 167, Training loss: 2.302583
# Test accuracy : 0.1718
#
# Epoch 168, Training loss: 2.302583
# Test accuracy : 0.1731
#
# Epoch 169, Training loss: 2.302583
# Test accuracy : 0.1739
#
# Epoch 170, Training loss: 2.302583
# Test accuracy : 0.1755
#
# Epoch 171, Training loss: 2.302583
# Test accuracy : 0.1765
#
# Epoch 172, Training loss: 2.302583
# Test accuracy : 0.1787
#
# Epoch 173, Training loss: 2.302583
# Test accuracy : 0.1799
#
# Epoch 174, Training loss: 2.302583
# Test accuracy : 0.1801
#
# Epoch 175, Training loss: 2.302583
# Test accuracy : 0.1804
#
# Epoch 176, Training loss: 2.302583
# Test accuracy : 0.1806
#
# Epoch 177, Training loss: 2.302583
# Test accuracy : 0.18
#
# Epoch 178, Training loss: 2.302583
# Test accuracy : 0.1807
#
# Epoch 179, Training loss: 2.302583
# Test accuracy : 0.1817
#
# Epoch 180, Training loss: 2.302583
# Test accuracy : 0.1829
#
# Epoch 181, Training loss: 2.302583
# Test accuracy : 0.1835
#
# Epoch 182, Training loss: 2.302583
# Test accuracy : 0.1842
#
# Epoch 183, Training loss: 2.302583
# Test accuracy : 0.185
#
# Epoch 184, Training loss: 2.302583
# Test accuracy : 0.1857
#
# Epoch 185, Training loss: 2.302583
# Test accuracy : 0.1863
#
# Epoch 186, Training loss: 2.302583
# Test accuracy : 0.1869
#
# Epoch 187, Training loss: 2.302583
# Test accuracy : 0.1862
#
# Epoch 188, Training loss: 2.302583
# Test accuracy : 0.1863
#
# Epoch 189, Training loss: 2.302583
# Test accuracy : 0.1869
#
# Epoch 190, Training loss: 2.302583
# Test accuracy : 0.187
#
# Epoch 191, Training loss: 2.302583
# Test accuracy : 0.187
#
# Epoch 192, Training loss: 2.302583
# Test accuracy : 0.1877
#
# Epoch 193, Training loss: 2.302582
# Test accuracy : 0.1874
#
# Epoch 194, Training loss: 2.302582
# Test accuracy : 0.188
#
# Epoch 195, Training loss: 2.302582
# Test accuracy : 0.1886
#
# Epoch 196, Training loss: 2.302582
# Test accuracy : 0.1885
#
# Epoch 197, Training loss: 2.302582
# Test accuracy : 0.1885
#
# Epoch 198, Training loss: 2.302582
# Test accuracy : 0.1883
#
# Epoch 199, Training loss: 2.302582
# Test accuracy : 0.1885
#
# Epoch 200, Training loss: 2.302582
# Test accuracy : 0.1886
#
# Epoch 201, Training loss: 2.302582
# Test accuracy : 0.188
#
# Epoch 202, Training loss: 2.302582
# Test accuracy : 0.1879
#
# Epoch 203, Training loss: 2.302582
# Test accuracy : 0.1882
#
# Epoch 204, Training loss: 2.302582
# Test accuracy : 0.1883
#
# Epoch 205, Training loss: 2.302582
# Test accuracy : 0.1889
#
# Epoch 206, Training loss: 2.302582
# Test accuracy : 0.1898
#
# Epoch 207, Training loss: 2.302582
# Test accuracy : 0.1901
#
# Epoch 208, Training loss: 2.302582
# Test accuracy : 0.19
#
# Epoch 209, Training loss: 2.302582
# Test accuracy : 0.1901
#
# Epoch 210, Training loss: 2.302582
# Test accuracy : 0.1905
#
# Epoch 211, Training loss: 2.302582
# Test accuracy : 0.1899
#
# Epoch 212, Training loss: 2.302582
# Test accuracy : 0.1898
#
# Epoch 213, Training loss: 2.302582
# Test accuracy : 0.1897
#
# Epoch 214, Training loss: 2.302582
# Test accuracy : 0.1896
#
# Epoch 215, Training loss: 2.302582
# Test accuracy : 0.1898
#
# Epoch 216, Training loss: 2.302582
# Test accuracy : 0.1899
#
# Epoch 217, Training loss: 2.302582
# Test accuracy : 0.1907
#
# Epoch 218, Training loss: 2.302582
# Test accuracy : 0.1902
#
# Epoch 219, Training loss: 2.302582
# Test accuracy : 0.1905
#
# Epoch 220, Training loss: 2.302582
# Test accuracy : 0.1904
#
# Epoch 221, Training loss: 2.302582
# Test accuracy : 0.1907
#
# Epoch 222, Training loss: 2.302582
# Test accuracy : 0.1904
#
# Epoch 223, Training loss: 2.302582
# Test accuracy : 0.1908
#
# Epoch 224, Training loss: 2.302582
# Test accuracy : 0.1908
#
# Epoch 225, Training loss: 2.302582
# Test accuracy : 0.1904
#
# Epoch 226, Training loss: 2.302582
# Test accuracy : 0.1903
#
# Epoch 227, Training loss: 2.302582
# Test accuracy : 0.1903
#
# Epoch 228, Training loss: 2.302582
# Test accuracy : 0.1902
#
# Epoch 229, Training loss: 2.302582
# Test accuracy : 0.1903
#
# Epoch 230, Training loss: 2.302582
# Test accuracy : 0.1904
#
# Epoch 231, Training loss: 2.302582
# Test accuracy : 0.1902
#
# Epoch 232, Training loss: 2.302582
# Test accuracy : 0.1903
#
# Epoch 233, Training loss: 2.302582
# Test accuracy : 0.1902
#
# Epoch 234, Training loss: 2.302582
# Test accuracy : 0.1904
#
# Epoch 235, Training loss: 2.302582
# Test accuracy : 0.1904
#
# Epoch 236, Training loss: 2.302582
# Test accuracy : 0.1906
#
# Epoch 237, Training loss: 2.302582
# Test accuracy : 0.1902
#
# Epoch 238, Training loss: 2.302582
# Test accuracy : 0.1903
#
# Epoch 239, Training loss: 2.302582
# Test accuracy : 0.1908
#
# Epoch 240, Training loss: 2.302582
# Test accuracy : 0.1907
#
# Epoch 241, Training loss: 2.302582
# Test accuracy : 0.1911
#
# Epoch 242, Training loss: 2.302582
# Test accuracy : 0.1913
#
# Epoch 243, Training loss: 2.302582
# Test accuracy : 0.1913
#
# Epoch 244, Training loss: 2.302582
# Test accuracy : 0.1912
#
# Epoch 245, Training loss: 2.302582
# Test accuracy : 0.1912
#
# Epoch 246, Training loss: 2.302582
# Test accuracy : 0.1915
#
# Epoch 247, Training loss: 2.302582
# Test accuracy : 0.1917
#
# Epoch 248, Training loss: 2.302582
# Test accuracy : 0.1923
#
# Epoch 249, Training loss: 2.302582
# Test accuracy : 0.1925
#
# Epoch 250, Training loss: 2.302582
# Test accuracy : 0.1924
#
# Epoch 251, Training loss: 2.302582
# Test accuracy : 0.1926
#
# Epoch 252, Training loss: 2.302582
# Test accuracy : 0.1925
#
# Epoch 253, Training loss: 2.302582
# Test accuracy : 0.1924
#
# Epoch 254, Training loss: 2.302582
# Test accuracy : 0.1924
#
# Epoch 255, Training loss: 2.302582
# Test accuracy : 0.1922
#
# Epoch 256, Training loss: 2.302582
# Test accuracy : 0.192
#
# Epoch 257, Training loss: 2.302582
# Test accuracy : 0.1918
#
# Epoch 258, Training loss: 2.302582
# Test accuracy : 0.1916
#
# Epoch 259, Training loss: 2.302582
# Test accuracy : 0.192
#
# Epoch 260, Training loss: 2.302582
# Test accuracy : 0.1922
#
# Epoch 261, Training loss: 2.302582
# Test accuracy : 0.1923
#
# Epoch 262, Training loss: 2.302582
# Test accuracy : 0.1923
#
# Epoch 263, Training loss: 2.302582
# Test accuracy : 0.1922
#
# Epoch 264, Training loss: 2.302582
# Test accuracy : 0.1921
#
# Epoch 265, Training loss: 2.302582
# Test accuracy : 0.1921
#
# Epoch 266, Training loss: 2.302582
# Test accuracy : 0.1928
#
# Epoch 267, Training loss: 2.302582
# Test accuracy : 0.1929
#
# Epoch 268, Training loss: 2.302582
# Test accuracy : 0.1931
#
# Epoch 269, Training loss: 2.302582
# Test accuracy : 0.193
#
# Epoch 270, Training loss: 2.302582
# Test accuracy : 0.1929
#
# Epoch 271, Training loss: 2.302582
# Test accuracy : 0.1928
#
# Epoch 272, Training loss: 2.302582
# Test accuracy : 0.1928
#
# Epoch 273, Training loss: 2.302582
# Test accuracy : 0.193
#
# Epoch 274, Training loss: 2.302582
# Test accuracy : 0.1934
#
# Epoch 275, Training loss: 2.302582
# Test accuracy : 0.1936
#
# Epoch 276, Training loss: 2.302582
# Test accuracy : 0.1938
#
# Epoch 277, Training loss: 2.302582
# Test accuracy : 0.1938
#
# Epoch 278, Training loss: 2.302582
# Test accuracy : 0.1938
#
# Epoch 279, Training loss: 2.302582
# Test accuracy : 0.194
#
# Epoch 280, Training loss: 2.302582
# Test accuracy : 0.194
#
# Epoch 281, Training loss: 2.302582
# Test accuracy : 0.194
# Epoch 282, Training loss: 2.302582
# Test accuracy : 0.1942
#
# Epoch 283, Training loss: 2.302582
# Test accuracy : 0.1942
#
# Epoch 284, Training loss: 2.302582
# Test accuracy : 0.1941
#
# Epoch 285, Training loss: 2.302582
# Test accuracy : 0.1943
#
# Epoch 286, Training loss: 2.302582
# Test accuracy : 0.1941
#
# Epoch 287, Training loss: 2.302582
# Test accuracy : 0.1941
#
# Epoch 288, Training loss: 2.302582
# Test accuracy : 0.1943
#
# Epoch 289, Training loss: 2.302582
# Test accuracy : 0.1945
#
# Epoch 290, Training loss: 2.302582
# Test accuracy : 0.1949
#
# Epoch 291, Training loss: 2.302582
# Test accuracy : 0.195
#
# Epoch 292, Training loss: 2.302582
# Test accuracy : 0.195
#
# Epoch 293, Training loss: 2.302582
# Test accuracy : 0.195
#
# Epoch 294, Training loss: 2.302582
# Test accuracy : 0.1949
#
# Epoch 295, Training loss: 2.302582
# Test accuracy : 0.195
#
# Epoch 296, Training loss: 2.302582
# Test accuracy : 0.195
#
# Epoch 297, Training loss: 2.302582
# Test accuracy : 0.1951
#
# Epoch 298, Training loss: 2.302582
# Test accuracy : 0.1953
#
# Epoch 299, Training loss: 2.302582
# Test accuracy : 0.1952
